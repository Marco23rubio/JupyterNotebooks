# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as st

# %% [markdown]
# ###Generar una distribución

# %%
np.random.seed(20)
var1 = np.random.randint(0,10,10)##Dias de vacaciones
var2 = var1 + np.random.normal(0,1,10)#Dinero gastado

# %%
var1
var2
# Out:
# array([1.91516741, 9.55969629, 4.93946935, 5.02151896, 7.50309684,
#        2.40641447, 0.32346101, 5.50658912, 7.20798321, 4.15763207])

# %% [markdown]
# ### Visualizacion de datos con un intervalo de confianza

# %%
grafico = sns.regplot(x = var1, y = var2, ci=80)
grafico
# Out:
# <Axes: >

# %%
tuple = list(zip(var1,var2))
tuple
# Out:
# [(3, 1.9151674126826672),
#  (9, 9.559696289403918),
#  (4, 4.939469349856077),
#  (6, 5.021518957881304),
#  (7, 7.503096840109191),
#  (2, 2.406414468894801),
#  (0, 0.3234610099156434),
#  (6, 5.50658911809112),
#  (8, 7.207983209222818),
#  (5, 4.157632065861516)]

# %%
tabla = pd.DataFrame(tuple,columns=['Dias_vacaciones','Dinero_gastado'])
tabla
# Out:
#    Dias_vacaciones  Dinero_gastado
# 0                3        1.915167
# 1                9        9.559696
# 2                4        4.939469
# 3                6        5.021519
# 4                7        7.503097
# 5                2        2.406414
# 6                0        0.323461
# 7                6        5.506589
# 8                8        7.207983
# 9                5        4.157632

# %% [markdown]
# ###Calculo de intervalos de confianza

# %%
##95%
valores=st.t.interval(confidence=0.95,df=len(tabla)-1,loc=np.mean(tabla),scale=st.sem(tabla))
valores
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3430: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# (array([3.00496491, 2.84767315]), array([6.99503509, 6.86053259]))
